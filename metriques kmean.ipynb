# %% [markdown]
# ##Clustering metrics - alternatives to the elbow method
# Dr. Tirthajyoti Sarkar, Fremont, CA 94536
#
# Clustering is an important part of the machine learning pipeline for business or scientific enterprises utilizing data science. As the name suggests, it helps to identify congregations of closely related (by some measure of distance) data points in a blob of data, which, otherwise, would be difficult to make sense of.
#
# A popular method like k-means clustering does not seem to provide a completely satisfactory answer when we ask the basic question:
#
# "How would we know the actual number of clusters, to begin with?"
#
# This question is critically important because of the fact that the process of clustering is often a precursor to further processing of the individual cluster data and therefore, the amount of computational resource may depend on this measurement.
#
# In the case of a business analytics problem, repercussion could be worse. Clustering is often done for such analytics with the goal of market segmentation. It is, therefore, easily conceivable that, depending on the number of clusters, appropriate marketing personnel will be allocated to the problem. Consequently, a wrong assessment of the number of clusters can lead to sub-optimum allocation of precious resources.
#
# For the k-means clustering method, the most common approach for answering this question is the so-called elbow method. It involves running the algorithm multiple times over a loop, with an increasing number of cluster choice and then plotting a clustering score as a function of the number of clusters.
#
# In this notebook, we show what metric to use for visualizing and determining an optimal number of clusters much better than the usual practice - elbow method.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %% [markdown]
# Create synthetic data using Scikit learn make_blob method
# Number of features: 4
# Number of clusters: 5
# Number of samples: 200

# %%
n_features = 4
n_cluster = 5
cluster_std = 1.2
n_samples = 200

# %%
data1 = make_blobs(n_samples=n_samples,n_features=n_features,centers=n_cluster,cluster_std=cluster_std)

# %%
d1 = data1[0]

# %%
df1=pd.DataFrame(data=d1,columns=['Feature_'+str(i) for i in range(1,n_features+1)])
df1.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4
# 0   6.508449  -0.830010   9.881403  -6.239794
# 1   5.557156  -1.356767   9.130756  -4.764122
# 2   1.672162   7.034331  -2.089712  -3.144787
# 3   2.756249   4.696491   0.530929  -3.989956
# 4  -9.984604  -7.735340   6.304892  -0.817588

# %%
from itertools import combinations

# %%
lst_vars=list(combinations(df1.columns,2))

# %%
len(lst_vars)
# Out:
# 6

# %%
plt.figure(figsize=(15,8))
for i in range(1,7):
    plt.subplot(2,3,i)
    dim1=lst_vars[i-1][0]
    dim2=lst_vars[i-1][1]
    plt.scatter(df1[dim1],df1[dim2],c=data1[1],edgecolor='k',s=150)
    plt.xlabel(f"{dim1}",fontsize=13)
    plt.ylabel(f"{dim2}",fontsize=13)

# %%
plt.figure(figsize=(16,14))
for i,c in enumerate(df1.columns):
    plt.subplot(3,2,i+1)
    sns.boxplot(y=df1[c],x=data1[1])
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel("Class",fontsize=15)
    plt.ylabel(c,fontsize=15)
    #plt.show()

# %%
from sklearn.cluster import KMeans

# %%
X=df1

# %%
X.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4
# 0   6.508449  -0.830010   9.881403  -6.239794
# 1   5.557156  -1.356767   9.130756  -4.764122
# 2   1.672162   7.034331  -2.089712  -3.144787
# 3   2.756249   4.696491   0.530929  -3.989956
# 4  -9.984604  -7.735340   6.304892  -0.817588

# %%
y=data1[1]

# %%
#Scaling
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
#Metriques
from sklearn.metrics import silhouette_score, davies_bouldin_score,v_measure_score

# %%
km_scores= []
km_silhouette = []
vmeasure_score =[]
db_score = []
for i in range(2,12):
    km = KMeans(n_clusters=i, random_state=0).fit(X_scaled)
    preds = km.predict(X_scaled)
    
    print("Score for number of cluster(s) {}: {}".format(i,km.score(X_scaled)))
    km_scores.append(-km.score(X_scaled))
    
    silhouette = silhouette_score(X_scaled,preds)
    km_silhouette.append(silhouette)
    print("Silhouette score for number of cluster(s) {}: {}".format(i,silhouette))
    
    db = davies_bouldin_score(X_scaled,preds)
    db_score.append(db)
    print("Davies Bouldin score for number of cluster(s) {}: {}".format(i,db))
    
    v_measure = v_measure_score(y,preds)
    vmeasure_score.append(v_measure)
    print("V-measure score for number of cluster(s) {}: {}".format(i,v_measure))
    print("-"*100)
# Out:
# Score for number of cluster(s) 2: -28.97750435430622
# Silhouette score for number of cluster(s) 2: 0.539277836964288
# Davies Bouldin score for number of cluster(s) 2: 0.581683858337463
# V-measure score for number of cluster(s) 2: 0.47435098761403227
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 3: -10.802923321401403
# Silhouette score for number of cluster(s) 3: 0.625257166167028
# Davies Bouldin score for number of cluster(s) 3: 0.6041594352933896
# V-measure score for number of cluster(s) 3: 0.7918756684685209
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 4: -5.840607020528422
# Silhouette score for number of cluster(s) 4: 0.6590240424976785
# Davies Bouldin score for number of cluster(s) 4: 0.4790294253256695
# V-measure score for number of cluster(s) 4: 0.905746099275519
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 5: -3.4638398995565773
# Silhouette score for number of cluster(s) 5: 0.6331512013459141
# Davies Bouldin score for number of cluster(s) 5: 0.5313950771087065
# V-measure score for number of cluster(s) 5: 0.9854329348806474
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 6: -3.1377135436360324
# Silhouette score for number of cluster(s) 6: 0.5458596581404922
# Davies Bouldin score for number of cluster(s) 6: 0.7400641440210219
# V-measure score for number of cluster(s) 6: 0.9450254161378283
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 7: -2.8933912529895163
# Silhouette score for number of cluster(s) 7: 0.46659171984462616
# Davies Bouldin score for number of cluster(s) 7: 0.9378454125582706
# V-measure score for number of cluster(s) 7: 0.9102488063311188
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 8: -2.6359434015058714
# Silhouette score for number of cluster(s) 8: 0.40260353404608296
# Davies Bouldin score for number of cluster(s) 8: 1.080825381303466
# V-measure score for number of cluster(s) 8: 0.8659645515321603
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 9: -2.454866982463527
# Silhouette score for number of cluster(s) 9: 0.3310666029924852
# Davies Bouldin score for number of cluster(s) 9: 1.183895610450887
# V-measure score for number of cluster(s) 9: 0.8420897758106576
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 10: -2.313177472297116
# Silhouette score for number of cluster(s) 10: 0.32676374500062416
# Davies Bouldin score for number of cluster(s) 10: 1.187144938051685
# V-measure score for number of cluster(s) 10: 0.8202694524609121
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 11: -2.1452505427406177
# Silhouette score for number of cluster(s) 11: 0.2684350073419979
# Davies Bouldin score for number of cluster(s) 11: 1.2835456730653694
# V-measure score for number of cluster(s) 11: 0.7876260758598652
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The elbow method for determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_scores,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("K-means score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=vmeasure_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("V-measure score")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("The silhouette coefficient method \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_silhouette,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Silhouette score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=db_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Davies-Bouldin score")
plt.show()

# %%
from sklearn.mixture import GaussianMixture

# %%
gm_bic= []
gm_score=[]
for i in range(2,12):
    gm = GaussianMixture(n_components=i,n_init=10,tol=1e-3,max_iter=1000).fit(X_scaled)
    print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(X_scaled)))
    print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(X_scaled)))
    print("-"*100)
    gm_bic.append(-gm.bic(X_scaled))
    gm_score.append(gm.score(X_scaled))
# Out:
# BIC for number of cluster(s) 2: -875.3261226992137
# Log-likelihood score for number of cluster(s) 2: 2.572443315822767
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: -1154.4045613380947
# Log-likelihood score for number of cluster(s) 3: 3.4688263136655206
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: -1201.6424649548235
# Log-likelihood score for number of cluster(s) 4: 3.785607973952894
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: -1183.4955859686042
# Log-likelihood score for number of cluster(s) 5: 3.9389276777328974
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: -1135.6618537138606
# Log-likelihood score for number of cluster(s) 6: 4.0180302483415895
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: -1082.0202249706772
# Log-likelihood score for number of cluster(s) 7: 4.0826130777291825
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: -1039.262337050127
# Log-likelihood score for number of cluster(s) 8: 4.1744052591733585
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: -1001.1479242644688
# Log-likelihood score for number of cluster(s) 9: 4.277806128454764
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: -950.7910956215945
# Log-likelihood score for number of cluster(s) 10: 4.35060095809313
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: -908.2653190910971
# Log-likelihood score for number of cluster(s) 11: 4.442973418012437
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The Gaussian Mixture model BIC \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=np.log(gm_bic),s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Log of Gaussian mixture BIC score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=gm_score,s=150,edgecolor='k')
plt.show()
