# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel('ducati_monster_s.xlsx')

# %%
df.head()
# Out:
#    Mois  Annee     km  Pot   Prix
# 0     3   2017   9770    0  12390
# 1     4   2017  19524    1  12900
# 2     4   2019   1500    0  13980
# 3     1   2017  10500    0  12900
# 4     3   2017  12300    0  12990

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mois    33 non-null     int64
#  1   Annee   33 non-null     int64
#  2   km      33 non-null     int64
#  3   Pot     33 non-null     int64
#  4   Prix    33 non-null     int64
# dtypes: int64(5)
# memory usage: 1.4 KB

# %%
df.describe()
# Out:
#             Mois        Annee            km        Pot          Prix
# count  33.000000    33.000000     33.000000  33.000000     33.000000
# mean    4.818182  2017.878788   6613.727273   0.393939  14076.909091
# std     3.046048     0.892944   6110.269825   0.496198   1331.505336
# min     1.000000  2017.000000     10.000000   0.000000  10990.000000
# 25%     3.000000  2017.000000   1980.000000   0.000000  12999.000000
# 50%     4.000000  2018.000000   4531.000000   0.000000  13980.000000
# 75%     6.000000  2019.000000   9770.000000   1.000000  14990.000000
# max    12.000000  2019.000000  24680.000000   1.000000  16490.000000

# %%
df.tail()
# Out:
#     Mois  Annee    km  Pot   Prix
# 28     2   2018   615    1  15900
# 29     3   2017  7276    1  12999
# 30     9   2019  2000    0  14990
# 31     4   2017  5600    0  12500
# 32     8   2017  4200    1  13390

# %%
df.loc[:3]
# Out:
#    Mois  Annee     km  Pot   Prix
# 0     3   2017   9770    0  12390
# 1     4   2017  19524    1  12900
# 2     4   2019   1500    0  13980
# 3     1   2017  10500    0  12900

# %%
df.iloc[:3]
# Out:
#    Mois  Annee     km  Pot   Prix
# 0     3   2017   9770    0  12390
# 1     4   2017  19524    1  12900
# 2     4   2019   1500    0  13980

# %%
df.loc[[0,1]]
# Out:
#    Mois  Annee     km  Pot   Prix
# 0     3   2017   9770    0  12390
# 1     4   2017  19524    1  12900

# %%
df.loc[0:1]
# Out:
#    Mois  Annee     km  Pot   Prix
# 0     3   2017   9770    0  12390
# 1     4   2017  19524    1  12900

# %%
df.iloc[0,1]
# Out:
# 2017

# %%
df.iloc[3:12,:]
# Out:
#     Mois  Annee     km  Pot   Prix
# 3      1   2017  10500    0  12900
# 4      3   2017  12300    0  12990
# 5      3   2017  11600    1  13900
# 6      3   2019     10    0  15990
# 7      4   2017  24680    1  10990
# 8      4   2017  13920    0  15790
# 9      3   2017   3400    1  13200
# 10    11   2019   2218    0  16490
# 11     1   2018   4531    1  13900

# %%
index_lignes=[]
for i in range(df.shape[0]):
    index_lignes.append('moto'+str(i))

# %%
df.index=index_lignes

# %%
df.head()
# Out:
#        Mois  Annee     km  Pot   Prix
# moto0     3   2017   9770    0  12390
# moto1     4   2017  19524    1  12900
# moto2     4   2019   1500    0  13980
# moto3     1   2017  10500    0  12900
# moto4     3   2017  12300    0  12990

# %%
df.loc['moto10':'moto15']
# Out:
#         Mois  Annee    km  Pot   Prix
# moto10    11   2019  2218    0  16490
# moto11     1   2018  4531    1  13900
# moto12     6   2019  1065    0  14300
# moto13     1   2019  2990    1  15490
# moto14     4   2019  1892    0  14990
# moto15     9   2017  7483    1  13299

# %%
df.loc['moto10':'moto15',['Annee','Prix']]
# Out:
#         Annee   Prix
# moto10   2019  16490
# moto11   2018  13900
# moto12   2019  14300
# moto13   2019  15490
# moto14   2019  14990
# moto15   2017  13299

# %%
df.iloc[[0,1]]
# Out:
#        Mois  Annee     km  Pot   Prix
# moto0     3   2017   9770    0  12390
# moto1     4   2017  19524    1  12900

# %%
df.iloc[0,1]
# Out:
# 2017

# %%
df.loc[['moto0','moto1']]
# Out:
#        Mois  Annee     km  Pot   Prix
# moto0     3   2017   9770    0  12390
# moto1     4   2017  19524    1  12900

# %%
df[['Annee','Prix']].count()
# Out:
# Annee    33
# Prix     33
# dtype: int64

# %%
df[df['Annee']>=2019]
# Out:
#         Mois  Annee    km  Pot   Prix
# moto2      4   2019  1500    0  13980
# moto6      3   2019    10    0  15990
# moto10    11   2019  2218    0  16490
# moto12     6   2019  1065    0  14300
# moto13     1   2019  2990    1  15490
# moto14     4   2019  1892    0  14990
# moto16     9   2019  1980    0  14990
# moto18     5   2019   500    0  14990
# moto22     4   2019  1892    0  14990
# moto23    12   2019   150    0  14990
# moto30     9   2019  2000    0  14990

# %%
df.isnull()
# Out:
#          Mois  Annee     km    Pot   Prix
# moto0   False  False  False  False  False
# moto1   False  False  False  False  False
# moto2   False  False  False  False  False
# moto3   False  False  False  False  False
# moto4   False  False  False  False  False
# moto5   False  False  False  False  False
# moto6   False  False  False  False  False
# moto7   False  False  False  False  False
# moto8   False  False  False  False  False
# moto9   False  False  False  False  False
# moto10  False  False  False  False  False
# moto11  False  False  False  False  False
# moto12  False  False  False  False  False
# moto13  False  False  False  False  False
# moto14  False  False  False  False  False
# moto15  False  False  False  False  False
# moto16  False  False  False  False  False
# moto17  False  False  False  False  False
# moto18  False  False  False  False  False
# moto19  False  False  False  False  False
# moto20  False  False  False  False  False
# ...

# %%
df.sample(n=5) #5 motos prises au hasard
# Out:
#         Mois  Annee     km  Pot   Prix
# moto7      4   2017  24680    1  10990
# moto19     4   2018   2800    0  14890
# moto31     4   2017   5600    0  12500
# moto32     8   2017   4200    1  13390
# moto8      4   2017  13920    0  15790

# %%
df[['km','Prix']].plot(bins=10,kind='hist',subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a16a47fd0>,
# ...
#       dtype=object)

# %%
df[['km','Prix']].hist(by=df.Annee)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1739c850>,
# ...
#       dtype=object)

# %%
df.km.hist(bins=10,density=0.1)

# %%
df.Prix.plot()

# %%
df.sort_values(by='Annee')
# Out:
#         Mois  Annee     km  Pot   Prix
# moto0      3   2017   9770    0  12390
# moto29     3   2017   7276    1  12999
# moto27     4   2017  17902    1  14990
# moto21     2   2017  14000    0  11300
# moto20     4   2017   8840    0  13490
# moto31     4   2017   5600    0  12500
# moto15     9   2017   7483    1  13299
# moto9      3   2017   3400    1  13200
# moto32     8   2017   4200    1  13390
# moto7      4   2017  24680    1  10990
# moto1      4   2017  19524    1  12900
# moto3      1   2017  10500    0  12900
# moto8      4   2017  13920    0  15790
# moto5      3   2017  11600    1  13900
# moto4      3   2017  12300    0  12990
# moto17     6   2018   7115    1  14990
# moto19     4   2018   2800    0  14890
# moto28     2   2018    615    1  15900
# moto11     1   2018   4531    1  13900
# moto26    12   2018   6000    0  13900
# moto24     3   2018   4500    0  12990
# moto25     4   2018   5500    1  14750
# moto6      3   2019     10    0  15990
# ...

# %%
df[df.groupby('Annee').cumcount()==5]
# Out:
#         Mois  Annee     km  Pot   Prix
# moto7      4   2017  24680    1  10990
# moto14     4   2019   1892    0  14990
# moto26    12   2018   6000    0  13900

# %%
df.sort_values(by=['Annee','Prix'],ascending=False)
# Out:
#         Mois  Annee     km  Pot   Prix
# moto10    11   2019   2218    0  16490
# moto6      3   2019     10    0  15990
# moto13     1   2019   2990    1  15490
# moto14     4   2019   1892    0  14990
# moto16     9   2019   1980    0  14990
# moto18     5   2019    500    0  14990
# moto22     4   2019   1892    0  14990
# moto23    12   2019    150    0  14990
# moto30     9   2019   2000    0  14990
# moto12     6   2019   1065    0  14300
# moto2      4   2019   1500    0  13980
# moto28     2   2018    615    1  15900
# moto17     6   2018   7115    1  14990
# moto19     4   2018   2800    0  14890
# moto25     4   2018   5500    1  14750
# moto11     1   2018   4531    1  13900
# moto26    12   2018   6000    0  13900
# moto24     3   2018   4500    0  12990
# moto8      4   2017  13920    0  15790
# moto27     4   2017  17902    1  14990
# moto5      3   2017  11600    1  13900
# moto20     4   2017   8840    0  13490
# moto32     8   2017   4200    1  13390
# ...

# %%
df.Annee!=df.Annee.shift()
# Out:
# moto0      True
# moto1     False
# moto2      True
# moto3      True
# moto4     False
# moto5     False
# moto6      True
# moto7      True
# moto8     False
# moto9     False
# moto10     True
# moto11     True
# moto12     True
# moto13    False
# moto14    False
# moto15     True
# moto16     True
# moto17     True
# moto18     True
# moto19     True
# moto20     True
# moto21    False
# moto22     True
# moto23    False
# moto24     True
# moto25    False
# moto26    False
# moto27     True
# moto28     True
# moto29     True
# moto30     True
# moto31     True
# moto32    False
# Name: Annee, dtype: bool

# %%
for index,ligne in df.iterrows():
    print(ligne['Annee'],ligne['km'])
# Out:
# 2017 9770
# 2017 19524
# 2019 1500
# 2017 10500
# 2017 12300
# 2017 11600
# 2019 10
# 2017 24680
# 2017 13920
# 2017 3400
# 2019 2218
# 2018 4531
# 2019 1065
# 2019 2990
# 2019 1892
# 2017 7483
# 2019 1980
# 2018 7115
# 2019 500
# 2018 2800
# 2017 8840
# 2017 14000
# 2019 1892
# 2019 150
# 2018 4500
# 2018 5500
# 2018 6000
# 2017 17902
# 2018 615
# 2017 7276
# 2019 2000
# 2017 5600
# 2017 4200

# %%
#recherche  où il y des Nan
df.isna().any()
# Out:
# Mois     False
# Annee    False
# km       False
# Pot      False
# Prix     False
# dtype: bool

# %%
df.columns
# Out:
# Index(['Mois', 'Annee', 'km', 'Pot', 'Prix'], dtype='object')

# %%
#recherche les colonne où il y des Nan
df.columns[df.isna().any()].tolist()
# Out:
# []

# %%
df.loc[:,df.isna().any()]
# Out:
# Empty DataFrame
# Columns: []
# Index: [moto0, moto1, moto2, moto3, moto4, moto5, moto6, moto7, moto8, moto9, moto10, moto11, moto12, moto13, moto14, moto15, moto16, moto17, moto18, moto19, moto20, moto21, moto22, moto23, moto24, moto25, moto26, moto27, moto28, moto29, moto30, moto31, moto32]

# %%
#transposée
df.T.head()
# Out:
#        moto0  moto1  moto2  moto3  moto4  moto5  moto6  moto7  moto8  moto9  \
# Mois       3      4      4      1      3      3      3      4      4      3
# Annee   2017   2017   2019   2017   2017   2017   2019   2017   2017   2017
# km      9770  19524   1500  10500  12300  11600     10  24680  13920   3400
# Pot        0      1      0      0      0      1      0      1      0      1
# Prix   12390  12900  13980  12900  12990  13900  15990  10990  15790  13200
#
#        ...  moto23  moto24  moto25  moto26  moto27  moto28  moto29  moto30  \
# Mois   ...      12       3       4      12       4       2       3       9
# Annee  ...    2019    2018    2018    2018    2017    2018    2017    2019
# km     ...     150    4500    5500    6000   17902     615    7276    2000
# Pot    ...       0       0       1       0       1       1       1       0
# Prix   ...   14990   12990   14750   13900   14990   15900   12999   14990
#
#        moto31  moto32
# Mois        4       8
# ...

# %%
df.sum(axis=0)
# Out:
# Mois        159
# Annee     66590
# km       218253
# Pot          13
# Prix     464538
# dtype: int64

# %%
from pandas_profiling import ProfileReport

# %%
Rapport=ProfileReport(df)

# %%
Rapport
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-05-26 08:21:18.564382&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#plt.figure(figsize=(horizontal_length,vertical_length))
plt.figure(figsize=(10,7))

# %%
#sns.set_style(name_of_style)
sns.set_style('whitegrid')

# %%
#sns.set_context(name_of_context)
sns.set_context('talk')

# %%
#sns.set_palette(name_of_palette)
#sns.set_palette('name_of_palette')
#'name_of_palette' is not a valid value for name; supported values are 
#'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
sns.set_palette('ocean')

# %%
sns.palplot(sns.color_palette('ocean', 15))

# %%
sns.distplot(df.Prix,bins=10,rug=10,kde=True)

# %%
sns.kdeplot(df.Prix)

# %%
sns.kdeplot(df.km,df.Prix,shade=True)

# %%
sns.jointplot(df.km,df.Prix,kind='scatter')

# %%
sns.pairplot(df)

# %%
sns.stripplot(df.km,df.Prix,orient='h')

# %%
sns.swarmplot(df.km,df.Prix,orient='h')

# %%
sns.violinplot(df.km,df.Prix,orient='h')

# %%
tips = sns.load_dataset("tips")
sns.lmplot(x="total_bill", y="tip", data=tips)

# %%
# x and y labels can be added with two commands: plt.xlabel(‘X Label’) and plt.ylabel(‘Y Label’).

# Title labels can be added with the command plt.title(‘Title’).

# Tick mark rotations can be added with plt.xticks(rotation=90) (and yticks for y-axis tick labels), 
# where 90 can be substituted with any suitable rotation degree.

# Axis value ranges can be specified with plt.xlim(lower_limit, upper_limit) 
# and plt.ylim(lower_limit, upper_limit). All values displayed for that dimension will be in between the specified limits. 
# These can also be used to set appropriate y-axis baselines for figures.

# Adding a legend, if it is not included by default, can be added with plt.legend(). 
# A parameter loc can be added to dictate where the legend should be. 
# By default, matplotlib finds the best location such that it doesn’t overlap with data points.

# %%
sns.stripplot(df.km,df.Prix)
plt.title('Prix et km')
plt.xticks(rotation=90)
plt.xlim(0,33)
plt.legend(df.index)
plt.show()
